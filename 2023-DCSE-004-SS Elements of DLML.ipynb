# %% [markdown]
# Cohort 3: Elements of Data Science and Machine Learning
#
#
# Test: TEST II (Practical Test)
#
# TIME ALLOWED : 3 hours
#
#
# Instruction: ATTEMPT A MAXIMUM OF THREE QUESTIONS INCLUDING QUESTION ONE
#
# (a) The Test is to understand your application concepts in class to complete a real-life data science project
#
# (b) It is NOT the best answers to earn marks but scientific approach to the problems in front of you
#
# (c) YOU ARE ONLY ALLOWED TO CONSULT YOUR NOTES OR NOTEBOOKS ONLY.

# %%
# Import libraries as neccessary 
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


# import any other library that may be of help in the course of the test (Zero Marks)

# %% [markdown]
# # Question 1: Data pre-processing and Exploration

# %%
# Read in TN middle school dataset from GitHub
# Run the code below to import the datataset and carryout preliminary data pre-processing including
df = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Essential%20Statistics/middle_tn_schools.csv')
# (i) explore the dataset characteristics (10 marks)
# (ii) check for any weird elements you see in the the dataset (5 marks)

# %% [markdown]
# Viewing the two variables:'reduced_lunch', 'school_rating'.
#
# Describe the relationship between these variables (5 marks)

# %%
fig, ax = plt.subplots(figsize=(14,8))

ax.set_ylabel(['school_rating'])

# boxplot with only these two variables

# Write code here (space below) to draw a boxplot below (5 marks)

# Explain what you see in the chart produced? (5 marks)

# %% [markdown]
# ## Question 2: Matrices and Numerical Python
#
# Construct a matrix below ;
#
# $$\left[\begin{array}{ccc} 1 & 0.2 & 0.5 \\ 0.2 & 1 & 0.8 \\ 0.5 & 0.8 & 1 \end{array}\right]$$
#
# as a NumPy array.
#
#
# (a). Compute an Inversion of the matrix (`Transpose`)
#
# (b). Computer the (`determinant`) of the matrix if possible

# %%
# Supply the code for the Question 2 (5 marks)
#computing an inverse of the matrix(Transpose)
import numpy as np

matrix = np.array([[1, 0.2, 0.5],[0.2, 1, 0.8],[0.5,0.8,1]])
matrix_transpose = np.transpose(matrix)

print(matrix_transpose)
# Out:
# [[1.  0.2 0.5]
#  [0.2 1.  0.8]
#  [0.5 0.8 1. ]]

# %%
#computing an inverse of the matrix (transpose)
import numpy as np

matrix_transpose = np.array([[1, 0.2,0.5], [0.2, 1,0.8],[0.5,0.8,1]])

inverse_matrix = np.linalg.inv(matrix_transpose)

print(inverse_matrix)
# Out:
# [[ 1.56521739  0.86956522 -1.47826087]
#  [ 0.86956522  3.26086957 -3.04347826]
#  [-1.47826087 -3.04347826  4.17391304]]

# %%
#computing the determinant of the matrix
import numpy as np
matrix = np.array([[1, 0.2, 0.5], [0.2, 1, 0.8], [0.5, 0.8, 1]])
# Calculate the determinant
determinant = np.linalg.det(matrix)
print("Determinant:", determinant)
# Out:
# Determinant: 0.2299999999999999

# %% [markdown]
# # Question 3: Visualization of Relationships

# %%
# Given this data. Format a working chart that plots christian and unaffiliation over time in Africa

year = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

christian = [77, 76, 75, 73, 73, 71, 69, 68, 67, 65]

unaffiliated = [17, 17, 19, 19, 20, 21, 24, 23, 25, 26]

# HINT: Pyplot provides a function called `plot' that makes a line plot. 
# It takes two sequences as arguments, the x values and the y values. 
# The sequences can be tuples, lists, or arrays.

# write your piece of code here (5 marks)
from numpy import random
#visualizations of relationships
import matplotlib.pyplot as plt
import seaborn as sns
year = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
christian = [77, 76, 75, 73, 73, 71, 69, 68, 67, 65]
unaffiliated = [17, 17, 19, 19, 20, 21, 24, 23, 25, 26]

plt.figure(figsize=(10, 6))

plt.plot(year, christian, marker='o', label='Christian')
plt.plot(year, unaffiliated, marker='o', label='Unaffiliated')

plt.title('A chart showing Percentage of Christian and Unaffiliated Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.xticks(year)  # Show all years on x-axis

plt.tight_layout()
plt.show()
# Explain the trend in the chart plot (3 marks)
# The trend in the chart is that there is a significatnt reduction in the numbers of christian compare to the increase in the numbers of affiliated over the years.

# %% [markdown]
# # Question 4: Visualization of Relationships

# %%
# Given the code that shows names of KFC & Cafe Javas burgers in Kamwokya

name_list = [
    'Lobster roll',
    'Chicken caesar',
    'Bang bang chicken',
    'Ham and cheese',
    'Tuna and cucumber',
    'Egg'
]

kfc_price_list = [9.99, 7.99, 7.49, 7, 6.29, 4.99]
cj_price_list = [7.5, 5, 4.4, 5, 3.75, 2.25]

# HINT:  As you should have observed that in the previous Question, the chat plotted percentages on the `y` axis versus time on the `x` axis.
# Now we want to plot the sandwich names on the `y` axis and the prices on the `x` axis. See here sample code: 

plt.plot(kfc_price_list, name_list)
plt.xlabel('Price in USD');

# Modify this code to change the line graph into dot using the markers argument 'o' (5 marks)
import matplotlib.pyplot as plt

name_list = [
    'Lobster roll',
    'Chicken caesar',
    'Bang bang chicken',
    'Ham and cheese',
    'Tuna and cucumber',
    'Egg'
]

kfc_price_list = [9.99, 7.99, 7.49, 7, 6.29, 4.99]
cj_price_list = [7.5, 5, 4.4, 5, 3.75, 2.25]

# Plotting
plt.figure(figsize=(8, 6))

plt.plot(kfc_price_list, name_list, 'o', label='KFC Prices')
plt.plot(cj_price_list, name_list, 'o', label='CJ Prices')

plt.xlabel('Price in USD')
plt.title('Sandwich Prices Comparison')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Now modify the same code again adding other the line chart for the CJ as dots 
# with markers on the same graph (5 marks)
import matplotlib.pyplot as plt

name_list = [
    'Lobster roll',
    'Chicken caesar',
    'Bang bang chicken',
    'Ham and cheese',
    'Tuna and cucumber',
    'Egg'
]

kfc_price_list = [9.99, 7.99, 7.49, 7, 6.29, 4.99]
cj_price_list = [7.5, 5, 4.4, 5, 3.75, 2.25]

# Plotting
plt.figure(figsize=(8, 6))

plt.plot(kfc_price_list, name_list, 'o-', label='KFC Prices')  # KFC as a line chart
plt.scatter(cj_price_list, name_list, marker='o', label='CJ Prices')  # CJ as dots (markers)

plt.xlabel('Price in USD')
plt.title('Sandwich Prices Comparison')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Using the code below connect the dots for price points for KFC and CJ together using horizontal lines

plt.hlines(name_list, cj_price_list, kfc_price_list, color='gray')  # (5 marks)

import matplotlib.pyplot as plt

name_list = [
    'Lobster roll',
    'Chicken caesar',
    'Bang bang chicken',
    'Ham and cheese',
    'Tuna and cucumber',
    'Egg'
]

kfc_price_list = [9.99, 7.99, 7.49, 7, 6.29, 4.99]
cj_price_list = [7.5, 5, 4.4, 5, 3.75, 2.25]

# Plotting
plt.figure(figsize=(8, 6))

plt.plot(kfc_price_list, name_list, 'o-', label='KFC Prices')  # KFC as a line chart
plt.scatter(cj_price_list, name_list, marker='o', label='CJ Prices')  # CJ as dots (markers)

plt.xlabel('Price in USD')
plt.title('Sandwich Prices Comparison')
plt.legend()
plt.grid(True)

# Connecting points with horizontal lines
plt.hlines(name_list, cj_price_list, kfc_price_list, color='gray')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 5: Distribution (Bonus Optional Question)

# %%
# Run this code to install empiricaldist module for use on this Question 5
try:
    import empiricaldist
except ImportError:
    # %pip install empiricaldist
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for empiricaldist: filename=empiricaldist-0.7.2-py3-none-any.whl size=12220 sha256=b68937398d97c923d0c9395cd69d01b581301049ee18251667a410d1b81976c4
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\e1\3b\7b\9e05941453eeac3d404f25bd2afefa929395b35f6de9770be7
# Successfully built empiricaldist
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Applying th concepts of hypothesis testing and analysis (Use the dataset we have using in class)

# Do people tend to gain weight as they get older? Using the cohort 3 dataset with two variables of weight and age. 

# Plot a distribution of weight. (5 marks)

# Extract the variable `'AGE'` from the DataFrame you created and assign it to `age`(recode it as 'age'). (3 marks)

# Plot the PMF of `age` as a bar chart, using `Pmf` from `empiricaldist` (5 marks)
